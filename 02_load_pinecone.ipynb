# %%
import json, os, time
import copy


import pprint

# OPENAI
from openai import OpenAI

# LANGCHAIN
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores.utils import filter_complex_metadata
from langchain.schema import Document
from langchain_openai import OpenAIEmbeddings
from langchain.prompts.prompt import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.vectorstores import Chroma
from langchain_core.messages import AIMessage, HumanMessage
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_pinecone import PineconeVectorStore

# PINECONE
import pinecone
from pinecone.grpc import PineconeGRPC as Pinecone
from pinecone import ServerlessSpec

# GENERAL
from dotenv import find_dotenv, load_dotenv
from rich.console import Console

# %%
console = Console()
load_dotenv()
if load_dotenv():
    print("Success: .env file found with some environment variables")
else:
    print(
        "Caution: No environment variables found. Please create .env file in the root directory or add environment variables in the .env file"
    )
api_key = os.environ["OPENAI_API_KEY"]
PINECONE_API_KEY = os.environ["PINECONE_API_KEY"]
PINECONE_ENV = os.environ["PINECONE_ENV"]
PINCONE_INDEX = os.environ["PINECONE_INDEX"]

print(f"{PINECONE_API_KEY} | {PINECONE_ENV} | {PINCONE_INDEX}")
client = OpenAI()


if api_key:
    try:
        client.models.list()
        print("OPENAI_API_KEY is set and is valid:", api_key)
    except openai.APIError as e:
        print(f"OpenAI API returned an API Error: {e}")
        pass
    except openai.APIConnectionError as e:
        print(f"Failed to connect to OpenAI API: {e}")
        pass
    except openai.RateLimitError as e:
        print(f"OpenAI API request exceeded rate limit: {e}")
        pass

else:
    print("Please set you OpenAI API key as an environment variable OPENAI_API_KEY")
# Out:
# Success: .env file found with some environment variables
# 69a6ef84-1e2b-49ad-b93d-c012c8be1ca2 | us-east-1 | test
# OPENAI_API_KEY is set and is valid: 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

# %%
embedding_function = OpenAIEmbeddings()

# %%
# Initialize a client
pc = Pinecone(api_key=PINECONE_API_KEY, environment=PINECONE_ENV)

# %%
index_name = PINCONE_INDEX

# %%
print(pc.list_indexes().names())
# Out:
# ['test']

# %%
print(pc.Index(index_name).describe_index_stats())
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 0}},
#  'total_vector_count': 0}

# %%
client = OpenAI()


def get_embedding(text, model="text-embedding-3-small"):

    # text = text.replace("\n", " ")
    try:
        embedding = (
            client.embeddings.create(input=[text], model=model).data[0].embedding
        )
    except Exception as e:
        print(f"Embedding failed: {text} | {e}")
        embedding = None

    return embedding

# %%
# Wait for the index to be ready
index_name = PINCONE_INDEX
while not pc.describe_index(index_name).status["ready"]:
    time.sleep(1)
index = pc.Index(index_name)

# %%
# filename = "TMCB_43_2256640.pdf.json"
filename = "mindset.pdf.json"
persist_directory = "./data/db/chroma/"
data_json_directory = "./pdf_output/"

# get all the json from json file

file = data_json_directory + filename

console.print(f"File: {file}")

# import json data

with open(file) as f:
    data = json.load(f)

num_el = len(data)
print(f"{num_el} elements to load")
# Out:
# File: ./pdf_output/mindset.pdf.json
# 374 elements to load

# %%
for i in range(num_el):
    metadata = dict(data[i]["metadata"])
    el_type = data[i]["type"]
    page_number = metadata["page_number"]
    doc_id = data[i]["element_id"]
    content = data[i]["text"]
    embed = get_embedding(content)
    meta = {
        "doc_id": doc_id,
        "filename": filename,
        "page_number": page_number,
        "type": el_type,
        "content": content,
    }
    print(f"Upserting: {i} | {doc_id}")
    try:
        if embed is None:
            continue
            index.upsert(
                vectors=[
                    {"id": doc_id, "values": embed, "metadata": meta},
                ],
                namespace="",
            )
    except Exception as e:
        print(f"Upsert failed: {doc_id}\n{e}")

# See how many vectors have been upserted
print("Index after upsert:")
print(pc.Index(index_name).describe_index_stats())
print("\n")
# Out:
# Upserting: 0 | 5ca69274a5fdd7bed6a160e7e686658e
# Upserting: 1 | 5739b692a97926a35a1675ef47a46733
# Upserting: 2 | b00b7517512ad9ab46c12bdf32d07972
# Upserting: 3 | a7e1220813696c0da336d0fdfd619487
# Upserting: 4 | fc8d4ac3c55e7ce3e5039298add4f1fd
# Upserting: 5 | c671e89b41f287a0b49c6318128fb1ef
# Upserting: 6 | c8c7244c09eeefef3cabb747021860a6
# Upserting: 7 | a180fa02107492026261de159d6110d1
# Upserting: 8 | fc7d0ce80265d1516a8b8da8fdfe0bd7
# Upserting: 9 | 8efbc87ad928fc52b9c464f1622616cb
# Upserting: 10 | 4fbd49b2ed0036405a805fd910ccdf67
# Upserting: 11 | 30f2f93f075a29f5680f68d95c2bd26f
# Upserting: 12 | 998e4d2b257d1f8829df94efca945b3b
# Upserting: 13 | 672cdb638408604d9a3d48f81a1b2416
# Upserting: 14 | ffd636104e8d8e14923f32cf07c99843
# Upserting: 15 | 2b6d45f990e2ceb02bdd27768e014090
# Upserting: 16 | 31a07596ce3abb4a47ce507a570ebbb2
# Upserting: 17 | dc6ab4cc71cd1f9301e4d6ec1c33db8d
# Upserting: 18 | 2c48cc5ca38752a97346fba5933f5c1a
# Upserting: 19 | d0e8e4a684826ff8fafb4ccd06e2a66b
# Upserting: 20 | 4b077fa05d34035f0ecc8fb748726e7b
# Upserting: 21 | 9cde2470edc06f024a91c9843d810366
# Upserting: 22 | 3fc9702847bbb078904a0644ebff032c
# Upserting: 23 | 44a61c1e54e2a52b529f1c47275e96d2
# Upserting: 24 | 1ed17b721ece44adde29a25ee2a8d364
# Upserting: 25 | a055d3a2116d30ab04a45aa9d1959695
# Upserting: 26 | 56d8b177db5994186bc01bf81795d7a7
# Upserting: 27 | 807e4c63ee69fb620f1401ceca872a42
# Upserting: 28 | f8bfd889862ad9e345ce360510dabe18
# Upserting: 29 | 5c81fc1fa652daafdd404d455688e2b2
# Upserting: 30 | 6334623489c38061517d834a2b7ba7a8
# Upserting: 31 | 6dc5a4e7a3a976aa4745fbc02a9d41e0
# Upserting: 32 | 36e9bbdca9c2ccf31ee2913a726ccad2
# Upserting: 33 | 7302f91f66da903bd5c0ec0589e25be5
# Upserting: 34 | 8d5304907880a0657c34fb87995397d5
# Upserting: 35 | 29d8afb880655ccbfab41bdfe3d7ad65
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 36 | 73fc26fee7edfde843dde217c1e61dc2
# Upserting: 37 | bec0d59e04f8ee59739f295219a1e288
# Upserting: 38 | e6fdf52b6b328f8112fcf785b5ab385f
# Upserting: 39 | 7c159c10fc727cc66020d7edc03be0da
# Upserting: 40 | 07f75f5fb880efe797d8f347e3933d77
# Upserting: 41 | 6688ad013b85a712a923dc538a933793
# Upserting: 42 | 895b6884c8a8c1f48e05ccedea84c4df
# Upserting: 43 | 19d1edbe09df7ad51a8990a92612dc7d
# Upserting: 44 | 1904e031a17c4049065bf2727ab95f3f
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 45 | dbb5e25f2750c5ad2da68e27fa2def08
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 46 | 357c4776172a547c189485fc81da7afc
# Upserting: 47 | 92d9cea368205ec461346539d222c917
# Upserting: 48 | 92f60a75d240f4bb613fb64e244ba595
# Upserting: 49 | 1f069fe8754ee259bfe89f7fefb04d8a
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 50 | 9187cc5bde6a26676efea41c5a43ceb0
# Upserting: 51 | edf007af6e200993ff6ac565546c09d8
# Upserting: 52 | cbc20577ca2ac62082af71e1ee0a5eb5
# Upserting: 53 | 315cc0c1ebf2c67cd16c979cf2a086ad
# Upserting: 54 | e8ae210d13b51a2ffc8d38df783777e4
# Upserting: 55 | 0dc67a96c613a7fcc97c1f5d2fd9b2c2
# Upserting: 56 | 9bc1f3036471c677dc394b35382e15bd
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 57 | 00424af03b8c2a197d262382b10834ed
# Upserting: 58 | ee0c3a0a7d9f35804913bb9490ee4bec
# Upserting: 59 | f5286237efbb542adc820b59e4d3c6fc
# Upserting: 60 | a839ec018713a85d3cb5c2f21c56cdc2
# Upserting: 61 | 4c14e9063ef4e4dde497070c494cabcd
# Upserting: 62 | 486abba26611052c39cdc17738fe540e
# Upserting: 63 | 7f3feeae4174483e41060813fb42f280
# Upserting: 64 | c01dcc66e6692c9020cf9d80bf1709cb
# Upserting: 65 | 1b8970716a36f339c2fd166d715ab869
# Upserting: 66 | 2d786b5acef2886bab1e451be5c8a937
# Upserting: 67 | 9db0c12533a14d62d3c81bb716a02034
# Upserting: 68 | 29051ca5fa08f80634c6dbb31439ee14
# Upserting: 69 | 4f64620dcf321664889f94fd2e90fe87
# Upserting: 70 | 064395048c3067e4688a1584f8d7da93
# Upserting: 71 | 33b39ab23930d530e6dc46bd1d63bda3
# Upserting: 72 | f7c208162cbc32d2b2232f984eb09954
# Upserting: 73 | 6d7f514c0103b9d7eb927a11a46f0f1e
# Upserting: 74 | 63d15f122e59de986b98fd63f33a9fb4
# Upserting: 75 | a236f61e1f293121fb2f843731ef86a8
# Upserting: 76 | 8d50d192994daf91400e23431bcabee3
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 77 | 719a27166d44b2344e4b3380ed2771e1
# Upserting: 78 | 597851e43dcb24aab53d61d9a5c9c203
# Upserting: 79 | d43c9946503c8f51f33771a0d5622a02
# Upserting: 80 | 1dd3cada37124b7086e4ba4d7940edfe
# Upserting: 81 | 0fb6d0e2145af5d943bcf327c7fb91e0
# Upserting: 82 | d6ef989695f00c21123d4871bb5681ea
# Upserting: 83 | cb580bde4987708699383917a0597906
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 84 | 6599c95ae551b1395edf3f03ccc7a0ef
# Upserting: 85 | b9423993989eda988d6f37699a84836b
# Upserting: 86 | 281e8aa19d1e32f49108d6a1959ea136
# Upserting: 87 | 7a4f82552dd121ae927b33e78f4576d5
# Upserting: 88 | 99f7cb18ad1936d77488e388c27f9b10
# Upserting: 89 | 4b324c9b6fc5f3b952fcc05d87d69069
# Upserting: 90 | 7f0c0f2002905bbb62eab024edb9c780
# Upserting: 91 | 00bae253e5ea2942f03f1a2186fd1626
# Upserting: 92 | fcbaa2e5b4d00d26f10b2e34d3c215e3
# Upserting: 93 | f84b604a8cdf6cab6bcddae80c1bb162
# Upserting: 94 | b692204562d481a67a7554aa4b248700
# Upserting: 95 | 171dfd5d124e2fc061ebc1db2953aeb9
# Upserting: 96 | a1ef5df3de426477ae6a0c54580f40f6
# Upserting: 97 | b42f0f721ac048d948f74340a5e5dacc
# Upserting: 98 | 1b35635fe551381d3f9f529340bb4cfc
# Upserting: 99 | ca4170f830e533b6330c077a735a6f49
# Upserting: 100 | c2c787bf7a4190cdc348229f9a254f06
# Upserting: 101 | 67e12dcaf296e155b6bf821540d1124f
# Upserting: 102 | b0a22b8296c14b2e185dbd6eb4f0f8a4
# Upserting: 103 | 08537bbfe163e368bbffbd9a6c49219f
# Upserting: 104 | 4b698e9372dce49acabb5ecf709e5f5b
# Upserting: 105 | 05d747f1948ec636d03f5891dfc55d0a
# Upserting: 106 | 1e36e89226ccec8fbb534f29e80243e4
# Upserting: 107 | e671b6e084a2d09b27d1ba3c7e62b67b
# Upserting: 108 | 2b65dc4cc48877cfe24f1de0b363c313
# Upserting: 109 | 38641923543bde255990961e9aaa9bc4
# Upserting: 110 | dc48d2113351649fa2d22fe79ddb4a51
# Upserting: 111 | 43c0adb2e1af243504a52ab7244c8432
# Upserting: 112 | b19918aace936563e12a9fd0623721af
# Upserting: 113 | c62ac29be14f1e2f69caf6a7b6adea35
# Upserting: 114 | 9c6c01cdab8e34ef829aede29177c518
# Upserting: 115 | 07b665743d636acc71a1740b8c6a1f87
# Upserting: 116 | 2183e47f68b63c3f9e0ed12e4502e662
# Upserting: 117 | 505210199cb07717ff9b6eb20cf52bd6
# Upserting: 118 | 9a6c1b24342ff6d8c8ba2b11c19c1b0e
# Upserting: 119 | 4ba6d440fe311470d7f13315abe44d9d
# Upserting: 120 | 50c9af0bbf8ddecd60e72a5197920d10
# Upserting: 121 | cb03968d85eb28ff4f0ecb6c3963341a
# Upserting: 122 | ec43e363fc43c70dd8e4fd148b2129b4
# Upserting: 123 | 8d2a66bf2562b20bd6af37ea60ab8981
# Upserting: 124 | 787a1672e5bdf18b7b8bdc282a7065d2
# Upserting: 125 | a31a04e6af9cdb0e6d5c84a891fdf807
# Upserting: 126 | e4933ef58ab05a69fa24f8de27e77290
# Upserting: 127 | 1ef1e71b9ce6bde80a7e5782e2f1737d
# Upserting: 128 | 8c1ec1a849110419214e2f3e11c61fc8
# Upserting: 129 | 600edaaef367199d67a732674e0c98a5
# Upserting: 130 | ed7d0ea46f91df95b40e576ef40b183b
# Upserting: 131 | 1f97dfa84a36313892a36a2eaf76e5e5
# Upserting: 132 | bf468472c7176d9c0c7e887501d863ae
# Upserting: 133 | 8190954e92904fbd6f3fb8357ff54786
# Upserting: 134 | 2064a1afbada2d69df90bfa7d4c7b1a4
# Upserting: 135 | ec12ece68807ee3cf34c4924300f5cca
# Upserting: 136 | c82c9b5549e6e774c6922387a15ffe90
# Upserting: 137 | 493846ea647f48ae9de1cba6f68c49f3
# Upserting: 138 | 382f66ca6dae4776dfd759931a109fc6
# Upserting: 139 | 3b78c53e2ec2083b41c0f8f68d825c71
# Upserting: 140 | e407407169bc7ef790dc4c48742e5b34
# Upserting: 141 | 6da07a69b936cbd460b968020f7381cf
# Upserting: 142 | d55036015d8a2d4eac6b7bcde46b15a0
# Upserting: 143 | 606c7f5f15ec466f04f23225f1aa9248
# Upserting: 144 | b9e4d9fcd5968e27f8b987415cb7cff4
# Upserting: 145 | 8938f8401b58bec57e06fc06de386737
# Upserting: 146 | 1894ba6453394475958cb32ee230c507
# Upserting: 147 | d2c4d67b61a02b8da3029d17cdf60a1b
# Upserting: 148 | 5eafc6b26610d601361b23a3269aee89
# Upserting: 149 | 969e43c7973d4e32fb663df9760813a7
# Upserting: 150 | 70041445d11cb010630d32fab1f0a6e3
# Upserting: 151 | ba72149bd5a208058bf49e00eee40496
# Upserting: 152 | 7c78faa5f1c9063187029930846f075a
# Upserting: 153 | edd2dbed3b71948fc67fa257e196b161
# Upserting: 154 | 7dffa4f87f74d84eb6f7025dfef66618
# Upserting: 155 | 3e6a9f335f2af62ee81dcfe65bca9d9c
# Upserting: 156 | 18a340e236dc8b619445563d799edfa3
# Upserting: 157 | c210cd6f447574f648ebfe814c251831
# Upserting: 158 | 626a0133b1729f5d4daa1528cb819f57
# Upserting: 159 | d8100010b6d962e28fe71f0a100c92c2
# Upserting: 160 | 6008dadf16a00c9f2d2aa61cf7553784
# Upserting: 161 | f73b0daaf5a64c31e53950bacd1dcb80
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 162 | 11703468df61a285918dac07c0d170a6
# Upserting: 163 | 510d71ede8758d2cec711a48ca4bdaef
# Upserting: 164 | bdc3d23a8cd2aa8811a948e9f4828bf1
# Upserting: 165 | 2113b0a59f4b5890b27f90528400c61a
# Upserting: 166 | 1a615f60d54baba0a4c284eee2cf99c1
# Upserting: 167 | 12b9e3c2dd393d6b4403e92fce7a63d4
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 168 | 62d6348213bc19aa6dea3554be59cddb
# Upserting: 169 | 9cbb0e26ba00d195b4f2413302969526
# Upserting: 170 | 468fc9213b108d374b36a65e596661df
# Upserting: 171 | 570cbfdcfcd64fe8d16520dc98e9e680
# Upserting: 172 | 67ed826d98561099056935a82702d8a5
# Upserting: 173 | fdac8c66ea368f1d4c7c9734149ac46e
# Upserting: 174 | 416a3b2e604e4ac7240e7a0db3b615c5
# Upserting: 175 | 8f9c2e8d6857102859a1e4e1ef30f07b
# Upserting: 176 | a37ad222e9f64d0a9d649fe3dba6d051
# Upserting: 177 | aa768cfef9497a9b39925389f3083a6c
# Upserting: 178 | 4c21e44cde147cd71f8f535f322d1b36
# Upserting: 179 | c4966e025188cfc3e095177490035321
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 180 | fabacf868a90b6085d36a06a591fcd72
# Upserting: 181 | 5ca842d4c8f0fd3066dc40fcec910c4d
# Upserting: 182 | 4ccfb5dd9643935f56106c4ec3c0e6e3
# Upserting: 183 | 33dd51e99c0b364c0432486791bb69b4
# Upserting: 184 | 28ca262b00e7d91036dc1d00e29fd3ca
# Upserting: 185 | 142f07ddf83c1b7baf69407f81d533f1
# Upserting: 186 | 60c2634a20613f34e750fea3be46a190
# Upserting: 187 | cbe1ceddb4b50003e1b1d1c242fbe4a2
# Upserting: 188 | 18c4789c0ff51ceefd4faf116c05d824
# Upserting: 189 | f86be749dcb2880d6715a5d73043278d
# Upserting: 190 | 2e5882a184d2a1f949aec2e8fc1d339c
# Upserting: 191 | 108e6ef65b893d586a0ad6170e88746c
# Upserting: 192 | 6fae284a0fbd5a6c15a045daef8c2ae9
# Upserting: 193 | f9e935098a0c36ec11ed96db00989426
# Upserting: 194 | fdabfdc740e80f5a8a26ab69b9e3be62
# Upserting: 195 | 490c2072b91c0a29030547d63ad5727e
# Upserting: 196 | 5198f5e46db46b9ad9b0ab50adefaa64
# Upserting: 197 | 1ea57b32364b7bb816e8f90654bacffc
# Upserting: 198 | e1c753ccfc450aa89b6d6e1c00020991
# Upserting: 199 | d4e1d38ff1d209741521dec10dc22256
# Upserting: 200 | 564eac144d36960ad6818c27d82ccd59
# Upserting: 201 | a1eb33466ed3e05bfafe3b338163ca40
# Upserting: 202 | ba02049e8d364417003fabd907c0a514
# Upserting: 203 | 38e6da7147d4a673910e6a74a22fde90
# Upserting: 204 | 8de24f785b2046fe0bf9111642d1274c
# Upserting: 205 | 18a309981ba757aa735ecebe494130c6
# Upserting: 206 | 52f86bd26d901c6f26d9a8c162cc3356
# Upserting: 207 | da7eff70322900f9f4c3886ce23951b4
# Upserting: 208 | f562ee523969806b7ba62471ac626216
# Upserting: 209 | 047614728608ac0adf46478bcb7ab741
# Upserting: 210 | 4fef1a09a1667bcd81ea5681f4d73a74
# Upserting: 211 | 966dc29da65e13ebfb1bb84e1dd482d1
# Upserting: 212 | 6f0799d03ffbb4127a238046c2ff0b67
# Upserting: 213 | 801166ae20bcef2de8a4d887d9af5091
# Upserting: 214 | 16ba691842b85e18425df5d03283658c
# Upserting: 215 | ecbe79806f335d7daddab6779e541e5e
# Upserting: 216 | dc184c28dcfca14703b3dee897e722d4
# Upserting: 217 | 495a6839e1232748ca39fa1aded45eb5
# Upserting: 218 | 8e66513b1b77a75fd3d4a9c787432f7a
# Upserting: 219 | 7c38d4152ccf60cc34b51558de7a57ed
# Upserting: 220 | 7645f21bc63113029f09d44e41ab9e09
# Upserting: 221 | 3cd8a5405c67c3ea2a71f95c2ab797af
# Upserting: 222 | 1870590ce641eb5a88289c35fef701a3
# Upserting: 223 | 134a141ba847e3a9e2aebc8d7864be08
# Upserting: 224 | c52026faf7c534c830ecb7a60d0ba419
# Upserting: 225 | 15d42d3cbb6362892004a0ab6824fc9b
# Upserting: 226 | eee7d208259fb62b5465a16f7a61ad9d
# Upserting: 227 | 999fb5018c1eefbca1917cd5ca9bd435
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 228 | 78b991020b11f6fb55a9ec2c487080cd
# Upserting: 229 | 82eadfabb182eea89ca98e3fae507ba7
# Upserting: 230 | e493fb7d0caeb11bedc60f34c2e61d6e
# Upserting: 231 | d095d51a721ec77eb8cb0a03541aa651
# Upserting: 232 | a110b0839cbfe5e01a76838e7d3c9d64
# Upserting: 233 | 5616e504647bfe1bdb62e7f014700e48
# Upserting: 234 | c692059ecc9d1cf67557536abf8c2007
# Upserting: 235 | d76babec0caa30f2d1c26d02c3d2d6a2
# Upserting: 236 | 64a341dc0b0768931d730e6be86ccf27
# Upserting: 237 | 16c91406068fdf4954c160f52c8b8670
# Upserting: 238 | d31acb04efe1fc8056b110ca8d13fdd5
# Upserting: 239 | 48266502aa885091e2c6ccef22c03244
# Upserting: 240 | 9ccc9259f6651c9acdad7cd5e1508921
# Upserting: 241 | 274d5a9e7e09b765b0b0afaa47c5806c
# Upserting: 242 | 5b63bf072ff748e4d71de7103cbfbed9
# Upserting: 243 | a2e4a86f828c9d094ac45669487d3956
# Upserting: 244 | 8d99c1476d67983b172627d91df4952c
# Upserting: 245 | 0f9761ff5e2f652b7be59ec87606e28f
# Upserting: 246 | 5d267be7b7db1ac26250ce70d5a36c33
# Upserting: 247 | 9315bb1bc2045d0a7693ef8462a8735e
# Upserting: 248 | 2c540b74fb0c373e4d4531ab821d1c72
# Upserting: 249 | 552e4e8964ceec27c339f4f58f7efef5
# Upserting: 250 | 434d1624bfb959397c0777497b7e8ccc
# Upserting: 251 | c555d3931e01343bd09e231ac571b928
# Upserting: 252 | 423ca50053fcd93a66dfa91fab41c0b9
# Upserting: 253 | 07157420aa569024507f923c26eda076
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 254 | 9992cd8d6f01b8292b611dca6fece420
# Upserting: 255 | 7c0c2072de393083f18f9ca7ae8ddba9
# Upserting: 256 | babc27b6e990471ed029586498951253
# Upserting: 257 | c2147d83207e53d36be09770366362cd
# Upserting: 258 | 96c815265cc4099716b45fa24961bdfb
# Upserting: 259 | 5d0cd604f874eed66c304480780ff0fb
# Upserting: 260 | bff48b656563b90ebfd4d7d757b56176
# Upserting: 261 | 6a0a86e00f4573590767fdf3347120b7
# Upserting: 262 | bc194f036f3a6f81053db0533be811ed
# Upserting: 263 | 486ef6e3e4d6480b678ae74d5bcaf508
# Upserting: 264 | 6230074bddc98eb2251597f0cd9aee5a
# Upserting: 265 | 1e85bf7f30e39dd898c7efa2b90d4429
# Upserting: 266 | 529e300480c2db884d4e6be90102a342
# Upserting: 267 | f21374b79061ac855390787b1d5308c5
# Upserting: 268 | 28cca9b80033c6b09adf515b6ddd56d5
# Upserting: 269 | 79177fde7fee2bca06c21b5d1a81bea1
# Upserting: 270 | 908f991793d1f7cecbca3386726dbb76
# Upserting: 271 | d45eecdacdc86005ac571f3a03eafa9d
# Upserting: 272 | 6b3508c3a22c224f847d5b4e98d01af4
# Upserting: 273 | b51399f7ca95e4666234aea1cecf5504
# Upserting: 274 | b742819b8b48c045a19c3213e46bd11c
# Upserting: 275 | 84dd721e973c79e03be193d3e9145a5d
# Upserting: 276 | 0f2517028d7d21c1aee62bd98094f584
# Upserting: 277 | 947dc5f2acec449260c1fe9cfb7292d7
# Upserting: 278 | 37b9160f09e4b9c4747e24d3694f3461
# Upserting: 279 | 342dc5d968218bce90ed15412a48439e
# Upserting: 280 | 75bb51de3f4e377103d545bc3e1dd9e3
# Upserting: 281 | 3645c8ffe361d8de2b89281369a4f21c
# Upserting: 282 | 37cbea109f42e6fc62dc2467a75a2b30
# Upserting: 283 | a7fb14a26ef88355997fdd97ea2e8056
# Upserting: 284 | 5c17cbbe901fba4cf3a1c1177a7d347e
# Upserting: 285 | 96064173a2cc788c29039387fec17097
# Upserting: 286 | c45c9e6376a5e8113ca29d2410e4f57f
# Upserting: 287 | 6da7261f892fca02abf021bf0b319593
# Upserting: 288 | 8f3028f6df4b03e2b68ce9cea830732e
# Upserting: 289 | 6f602d7f84e378ae9f7627e8486b9975
# Upserting: 290 | d84a0f44a7c8421072db65eefa473bd8
# Upserting: 291 | afc269a5da802c9f7734e1d36fcc45de
# Upserting: 292 | 531c98ad0f5ddc0114930755a649a285
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 293 | f57a7a5c39ed7ced19e6417ab2812ced
# Upserting: 294 | 7f5fc35acc67bb87022041d3baf135e1
# Upserting: 295 | 0f2a33eae32ce934a7de7bbf7e8e9cf8
# Upserting: 296 | f06ca959406db7b2192fbe370f6e2939
# Upserting: 297 | c1ffefdf6e12729b8f89f3b5ae589a7f
# Upserting: 298 | c435d3cebb18dff374ee8f821c83385a
# Upserting: 299 | 0b6b8879ad2dde7007244057cc25c0ce
# Upserting: 300 | f15da2cffb1cfeccffde706de9050094
# Upserting: 301 | f7bb65b438c0ba1d5209a8bda60471ea
# Upserting: 302 | 2dbeb57d4fa4634f20ac9b341a716927
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 303 | b75b6f9139c90b6ded1c86d93b815650
# Upserting: 304 | f9b7d49bd05edf702dc84657ed26ce28
# Upserting: 305 | 4426effafdefbee644c693afd2e63aae
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 306 | 17cfa5226483243280446d101238d120
# Upserting: 307 | 756962caed7239f9e457021a14338f74
# Upserting: 308 | 523764a04a22ebb0aa2b9db8da350ff8
# Upserting: 309 | 4aa17bf179b2b32133e91638d12c7ce2
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 310 | 53abd8982c1ae9853841f1db627db56e
# Upserting: 311 | e799b0706c3e6bb0722b7ee18eddb5ed
# Upserting: 312 | 3059742adf1dee558fd94fa2e23101df
# Upserting: 313 | a73a705e83dde383c78c255211c5073c
# Upserting: 314 | 70293b8f6807e1e9b260696df06f212e
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 315 | 3237e844f2f84f1d55d7ab5881f118ec
# Upserting: 316 | 675ca91c70f793a590d6b3e11602c221
# Upserting: 317 | 8ff645a18a52e0f26dc902338c4a9e1e
# Upserting: 318 | 3de3d1c00dc811e9723aa0b924391abf
# Upserting: 319 | 6f37880fd83136b0669b5b4d0c42b00c
# Upserting: 320 | 28867799beb612a8810d7bdbcd2f0675
# Upserting: 321 | bbb6706a1df22e5cd108044477684bc9
# Upserting: 322 | 8210471199945b6db98694663a6e66e5
# Upserting: 323 | 1e4ea57e709c9b2ab737780a53ba7c1c
# Upserting: 324 | bc205de6faa53943354a87e3ed74db95
# Upserting: 325 | a44d7728b1e0fe9e324545d55d28af1a
# Upserting: 326 | 3686339607a7b5d8d02d7a6414d5bf7b
# Upserting: 327 | 03a767daedfd0cc20a41c6168814af47
# Upserting: 328 | 3cf1888ae2d1a3b81848c94155e3363c
# Upserting: 329 | 510fad585e0e96b876059e33f39310d2
# Upserting: 330 | 2c3d6d67e6a8c6c2ef955394ad641983
# Upserting: 331 | 597d17cceab829b1452dd68b041d093f
# Upserting: 332 | 1d6e64ab3820e4f9d01c68e72a3f868b
# Upserting: 333 | 97b9df15f76ba7086d1201d27679b02d
# Upserting: 334 | 9f6584cbfe2eafd1922cc5bc7f554aeb
# Upserting: 335 | 9db8859d9145f5c1ef64f7bd4475f207
# Upserting: 336 | 1a3d827154d86ae4e76a97af6ab1663a
# Upserting: 337 | e0383b3785baa6251fa116f1d41c5e36
# Upserting: 338 | 8ff0598d2ce5718b508cb36a4782d724
# Upserting: 339 | 0d1c3238a7fbe71e187d0b89f269dbb5
# Upserting: 340 | 2966c907c4df8caed847faa73c11fb3d
# Upserting: 341 | da33ce95af88b963bf425e26e96462be
# Upserting: 342 | 0ab9c30d49dcee6f880548486114eff0
# Upserting: 343 | baeb6fe642c86fecb78ffded852954ae
# Upserting: 344 | f9e94aee7b3126d62dee9e2ff654e2b6
# Upserting: 345 | 5a1133c3e09e238b39c5591e000e1217
# Upserting: 346 | b2a4e422a6e1f650b81f12c16b2fcc1c
# Upserting: 347 | 94e4f2decea5d44e902ff596f2b4dbca
# Upserting: 348 | bc871adcbee7aebb520710b2c02a9185
# Upserting: 349 | c3fd3e39b5f4d574df1c04ffd53597f6
# Upserting: 350 | c86f019076d5ec8f3c2dec19ab29b276
# Upserting: 351 | 14636eadf3ae7f4380a1cfe4753db6e6
# Upserting: 352 | 8aadc08b311a08d87a80579a616796c3
# Upserting: 353 | 071928ca8835bfb6b82ba1ea9c362487
# Upserting: 354 | 506f0f3e84ba0c01504fc6488fed34d8
# Upserting: 355 | ca02947dafe0809f995aea3b29a30a2b
# Upserting: 356 | 59d382a3607dddf55fefcae2343fe057
# Upserting: 357 | b74a9a3cc2abebe2e01190df8dea200c
# Upserting: 358 | e671099de09df33dac8c6bfaa51a4833
# Upserting: 359 | 0902c05ff2255c3feb4f1d99b25be7a2
# Upserting: 360 | 7557e59f40f507763f1ff8f64f280faf
# Upserting: 361 | f44a9f5d693d7b298755b3c3e766dfb3
# Upserting: 362 | 9a4216fdc9db7fa95fa91cb9ac96613b
# Upserting: 363 | d445eb64078e5fd776b8160859c31a28
# Upserting: 364 | 75a5a096c16a965a68c0896754e8a03f
# Upserting: 365 | 9786711ce68eaefb6d9426dcf669ff3b
# Upserting: 366 | bd4516aac16382aa54ae0bc1fb2a691a
# Upserting: 367 | 8f955be5affec225a08c4ee0ca7acb8c
# Upserting: 368 | 35cdb8b814eb4c75d433ad93c95df973
# Upserting: 369 | 6a6fb4e5670a341f67abbc9231658cb1
# Upserting: 370 | 7ab08d8b0770780b67a5f6cbda6073c1
# Upserting: 371 | e1c57d785e9c6357bed3a35f411ab8e3
# Upserting: 372 | 0b6578a019bd2a4ec3827ae86adec080
# Embedding failed:  | Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# Upserting: 373 | 27a87d3e00833590beeb6e42f6164841
# Index after upsert:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 0}},
#  'total_vector_count': 0}
