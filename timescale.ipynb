# %%
# https://console.cloud.timescale.com/dashboard/services

# %%
import psycopg2

# %%
# PGPASSWORD=m9p3g6telmkuq12r
# PGUSER=tsdbadmin
# PGDATABASE=tsdb
# PGHOST=d51monpq14.ulzuebwbth.tsdb.cloud.timescale.com
# PGPORT=36302
# PGSSLMODE=require

# %%
CONNECTION = "postgres://tsdbadmin:m9p3g6telmkuq12r@d51monpq14.ulzuebwbth.tsdb.cloud.timescale.com:36302/tsdb?sslmode=require"

# %%
conn = psycopg2.connect(CONNECTION)
cursor = conn.cursor()
# use the cursor to interact with your database
cursor.execute("SELECT 'hello world'")
print(cursor.fetchone())
# Out:
# ('hello world',)

# %%
with psycopg2.connect(CONNECTION) as conn:
    cursor = conn.cursor()
    # use the cursor to interact with your database
    cursor.execute("SELECT * FROM persons")
    print(cursor.fetchall())
# Out:
# [('John', 'Doe', datetime.datetime(1995, 1, 5, 0, 0, tzinfo=datetime.timezone.utc), 'john.doe@postgresqltutorial.com'), ('Jane', 'Doe', datetime.datetime(1995, 2, 5, 0, 0, tzinfo=datetime.timezone.utc), 'jane.doe@postgresqltutorial.com')]

# %%
sql = """CREATE TABLE IF NOT EXISTS document_embedding  (
    id BIGINT PRIMARY KEY GENERATED BY DEFAULT AS IDENTITY,
    document_id BIGINT ,
    metadata JSONB,
    contents TEXT,
    embedding VECTOR(1536)
)"""

# with psycopg2.connect(CONNECTION) as conn:
#     cursor = conn.cursor()
#     # use the cursor to interact with your database
#     cursor.execute(sql)
#     conn.commit()

# %%
with psycopg2.connect(CONNECTION) as conn:
    cursor = conn.cursor()
    # use the cursor to interact with your database
    cursor.execute("SELECT * FROM persons")
    print(cursor.fetchall())
# Out:
# [('John', 'Doe', datetime.datetime(1995, 1, 5, 0, 0, tzinfo=datetime.timezone.utc), 'john.doe@postgresqltutorial.com'), ('Jane', 'Doe', datetime.datetime(1995, 2, 5, 0, 0, tzinfo=datetime.timezone.utc), 'jane.doe@postgresqltutorial.com')]

# %%
with psycopg2.connect(CONNECTION) as conn:
    cursor = conn.cursor()
    # use the cursor to interact with your database
    TABLE_NAME = "publisher"

    # cursor.execute(f"DROP TABLE IF EXISTS {TABLE_NAME}")

    # Creating table as per requirement
    sql = f"""CREATE TABLE IF NOT EXISTS {TABLE_NAME} (
                    publisher_id SERIAL PRIMARY KEY,
                    publisher_name VARCHAR(255) NOT NULL,
                    publisher_estd INT,
                    publsiher_location VARCHAR(255),
                    publsiher_type VARCHAR(255)

    )"""

    try:
        cursor.execute(sql)
        conn.commit()
        print(f"{TABLE_NAME} table created successfully........\n")

    except Exception as e:
        print(f"Error {e}")

    try:
        postgres_insert_query = f""" INSERT INTO {TABLE_NAME} (publisher_id,
        publisher_name, publisher_estd, publsiher_location, publsiher_type)
        VALUES (%s,%s,%s,%s,%s)"""

        record_to_insert = [
            (11, "Packt", 1950, "chennai", "books"),
            (21, "Springer", 1950, "chennai", "books"),
            (31, "Springer", 1950, "chennai", "articles"),
            (41, "Oxford", 1950, "chennai", "all"),
            (51, "MIT", 1950, "chennai", "books"),
        ]
        for i in record_to_insert:
            cursor.execute(postgres_insert_query, i)

            conn.commit()
            count = cursor.rowcount
            print(
                count,
                f"Record inserted successfully into {TABLE_NAME} table",
            )

    except (Exception, psycopg2.Error) as error:
        print("Failed to insert record into publisher table", error)

    try:
        postgreSQL_select_Query = f"select * from {TABLE_NAME}"

        cursor.execute(postgreSQL_select_Query)
        print(f"\nSelecting rows from {TABLE_NAME} table using cursor.fetchall")
        records = cursor.fetchall()

        for row in records:
            print(
                "publisher_id = ",
                row[0],
            )
            print("publisher_name = ", row[1])
            print("publisher_estd = ", row[2])
            print("publisher_location = ", row[3])
            print("publisher_type = ", row[4], "\n")

    except (Exception, psycopg2.Error) as error:
        print("Error while fetching data from PostgreSQL", error)
# Out:
# publisher table created successfully........
#
# 1 Record inserted successfully into publisher table
# 1 Record inserted successfully into publisher table
# 1 Record inserted successfully into publisher table
# 1 Record inserted successfully into publisher table
# 1 Record inserted successfully into publisher table
#
# Selecting rows from publisher table using cursor.fetchall
# publisher_id =  1
# publisher_name =  Packt
# publisher_estd =  1950
# publisher_location =  chennai
# publisher_type =  books
#
# publisher_id =  2
# publisher_name =  Springer
# publisher_estd =  1950
# publisher_location =  chennai
# publisher_type =  books
#
# publisher_id =  3
# publisher_name =  Springer
# publisher_estd =  1950
# publisher_location =  chennai
# publisher_type =  articles
#
# publisher_id =  4
# publisher_name =  Oxford
# publisher_estd =  1950
# publisher_location =  chennai
# publisher_type =  all
#
# publisher_id =  5
# publisher_name =  MIT
# publisher_estd =  1950
# publisher_location =  chennai
# publisher_type =  books
#
# publisher_id =  11
# publisher_name =  Packt
# publisher_estd =  1950
# publisher_location =  chennai
# publisher_type =  books
#
# publisher_id =  21
# publisher_name =  Springer
# publisher_estd =  1950
# publisher_location =  chennai
# publisher_type =  books
#
# publisher_id =  31
# publisher_name =  Springer
# publisher_estd =  1950
# publisher_location =  chennai
# publisher_type =  articles
#
# publisher_id =  41
# publisher_name =  Oxford
# publisher_estd =  1950
# publisher_location =  chennai
# publisher_type =  all
#
# publisher_id =  51
# publisher_name =  MIT
# publisher_estd =  1950
# publisher_location =  chennai
# publisher_type =  books

# %%
with psycopg2.connect(CONNECTION) as conn:
    cursor = conn.cursor()
    # use the cursor to interact with your database
    cursor.execute("SELECT * FROM publisher")
    print(cursor.fetchall())
# Out:
# [(1, 'Packt', 1950, 'chennai', 'books'), (2, 'Springer', 1950, 'chennai', 'books'), (3, 'Springer', 1950, 'chennai', 'articles'), (4, 'Oxford', 1950, 'chennai', 'all'), (5, 'MIT', 1950, 'chennai', 'books')]

# %%
cursor.close()
conn.close()
print("PostgreSQL connection is closed")
# Out:
# PostgreSQL connection is closed
